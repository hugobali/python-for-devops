# %% [markdown]
# # Tuples (`tuple`)
#
# Tuples are ordered, immutable sequences defined with parentheses `()`. Once created, their contents cannot be changed.

# %% [markdown]
# ## Characteristics and Use Cases
# - Ordered: items maintain position
# - Immutable: cannot add, remove, or change after creation
# - Useful for fixed records like coordinates, version numbers, or as dictionary keys

# %%
host_port = ("127.0.0.1", 300)
red_rgb = (255,0,0)
tuple_single_value = ("only-value",) ## Need to add trilling coma,
print(type(host_port))
print(type(red_rgb))
print(type(tuple_single_value))

print(f"Host: {host_port[0]}")
print(red_rgb[-2:])

#host_port[0] = "192.168.0.1" # TypeError, Tuples are inmutables.
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# Host: 127.0.0.1
# (0, 0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       8 print(f"Host: {host_port[0]}")
#       9 print(red_rgb[-2:])
# ---> 11 host_port[0] = "192.168.0.1"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Hands-on Exercise
# 1. Create a tuple `service_endpoint` with hostname and port values.
# 2. Print the hostname and port.
# 3. Attempt to modify an element (commented out to avoid error).

# %%
service_endpoint = ("web01", 443)
print(f"Hostname: {service_endpoint[0].upper()}, Port: {service_endpoint[1]}")
service_endpoint[1] = 80
# Out:
# Hostname: WEB01, Port: 443
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 service_endpoint = ("web01", 443)
#       2 print(f"Hostname: {service_endpoint[0].upper()}, Port: {service_endpoint[1]}")
# ----> 3 service_endpoint[1] = 80
#
# TypeError: 'tuple' object does not support item assignment
